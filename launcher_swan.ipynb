# %% [markdown]
# # `boohft-calib` launcher for SWAN
#
# This notebook runs the example configuration card on SWAN.

# %%
import sys
assert 'LCG_108' in sys.executable, \
    "Please start a SWAN session with the LCG_108 Python stack"

# %%
# The LCG_108 Python stack provides the required packages.

# %%
from launcher import launch

# Launch all steps
launch('cards/sfbdt/example_bb_PNetXbbVsQCD.yml')
